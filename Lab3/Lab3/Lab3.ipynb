# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Data Mining</b></center>
# <center><b><h1>Lab - 3</b></center>
# <pre>

# %% [markdown]
# ### 1)  First, you need to read the titanic dataset from local disk and display first five records

# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("titanic.csv",sep=',')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.set_index('PassengerId')
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# ### 2)  Identify Nominal, Ordinal, Binary and Numeric attributes from data sets and display all values.

# %%
nominal=['Name','Sex',"Cabin","Embarked","Ticket"]
ordinal=['Pclass']
binary=['Sex',"Surived"]
numaric=['Age','Fare','SibSp','Parch']

print("Nominal :",nominal)
print("Ordinal :",ordinal)
print("Binary :",binary)
print("Numaric :",numaric)
# Out:
# Nominal : ['Name', 'Sex', 'Cabin', 'Embarked', 'Ticket']
# Ordinal : ['Pclass']
# Binary : ['Sex', 'Surived']
# Numaric : ['Age', 'Fare', 'SibSp', 'Parch']

# %% [markdown]
# ### 3)  Identify symmetric and asymmetric binary attributes from data sets and display all values.

# %%
print("Survied values (asymmtric binary ) :")
print(df['Survived'].value_counts())
print("----------------------")
print("Gender Count (symmtric binary ) :")
print(df['Sex'].value_counts())
# Out:
# Survied values (asymmtric binary ) :
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64
# ----------------------
# Gender Count (symmtric binary ) :
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# ### 4)  For each quantitative attribute, calculate its average, standard deviation, minimum, mode, range and maximum values.

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
quantitative=['PassengerId','Survived','Pclass','Age','SibSp','Parch','Fare']
for i in quantitative:
    print(":::",i,":::")
    print("Mean :", df[i].mean())
    print("Avg :", df[i].std())
    print("Minumun :", df[i].min())
    print("Maximum :", df[i].max())
    print("Mode :", df[i].mode()[0])
    print("Range :", df[i].max()-df[i].min())
    print("---------------------------------")
# Out:
# ::: PassengerId :::
# Mean : 446.0
# Avg : 257.3538420152301
# Minumun : 1
# Maximum : 891
# Mode : 1
# Range : 890
# ---------------------------------
# ::: Survived :::
# Mean : 0.3838383838383838
# Avg : 0.4865924542648575
# Minumun : 0
# Maximum : 1
# Mode : 0
# Range : 1
# ---------------------------------
# ::: Pclass :::
# Mean : 2.308641975308642
# Avg : 0.836071240977049
# Minumun : 1
# Maximum : 3
# Mode : 3
# Range : 2
# ---------------------------------
# ::: Age :::
# Mean : 29.69911764705882
# Avg : 14.526497332334042
# Minumun : 0.42
# Maximum : 80.0
# Mode : 24.0
# Range : 79.58
# ---------------------------------
# ::: SibSp :::
# Mean : 0.5230078563411896
# Avg : 1.1027434322934317
# Minumun : 0
# Maximum : 8
# Mode : 0
# Range : 8
# ---------------------------------
# ::: Parch :::
# Mean : 0.38159371492704824
# Avg : 0.8060572211299483
# Minumun : 0
# Maximum : 6
# Mode : 0
# Range : 6
# ---------------------------------
# ::: Fare :::
# Mean : 32.204207968574636
# ...

# %% [markdown]
# ### 6)  For the qualitative attribute (class), count the frequency for each of its distinct values.

# %%
print("Passangr Class Frequency")
print(df['Pclass'].value_counts())
# Out:
# Passangr Class Frequency
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %% [markdown]
# ###  7) It is also possible to display the summary for all the attributes simultaneously in a table using the describe() function. If an attribute is quantitative, it will display its mean, standard deviation and various quantiles (including minimum, median, and maximum) values. If an attribute is qualitative, it will display its number of unique values and the top (most frequent) values.

# %%
print("\n Summery for numeric Attribute")
print(df.describe())
print("--------------------------------------------")
print("\n Summery for All Attribute for All")
print(df.describe(include='all'))
print("--------------------------------------------")
print("\n Summery for Category Attribute For Object")
print(df.describe(include=['object']))
# Out:
#  Summery for numeric Attribute
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200
# --------------------------------------------
#
# ...

# %% [markdown]
# ### 8)  For multivariate statistics, you can compute the covariance and correlation between pairs of attributes.

# %%
print("Covariance Matrix :")
print(df.cov(numeric_only=True))
print("--------------------------------------")
print("Correlarion Matrix :")
print(df.corr(numeric_only=True))
# Out:
# Covariance Matrix :
#               PassengerId  Survived     Pclass         Age      SibSp  \
# PassengerId  66231.000000 -0.626966  -7.561798  138.696504 -16.325843
# Survived        -0.626966  0.236772  -0.137703   -0.551296  -0.018954
# Pclass          -7.561798 -0.137703   0.699015   -4.496004   0.076599
# Age            138.696504 -0.551296  -4.496004  211.019125  -4.163334
# SibSp          -16.325843 -0.018954   0.076599   -4.163334   1.216043
# Parch           -0.342697  0.032017   0.012429   -2.344191   0.368739
# Fare           161.883369  6.221787 -22.830196   73.849030   8.748734
#
#                 Parch         Fare
# PassengerId -0.342697   161.883369
# Survived     0.032017     6.221787
# Pclass       0.012429   -22.830196
# Age         -2.344191    73.849030
# SibSp        0.368739     8.748734
# Parch        0.649728     8.661052
# Fare         8.661052  2469.436846
# --------------------------------------
# Correlarion Matrix :
# ...

# %%
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %% [markdown]
# ### 9) Display the histogram for Age attribute by discretizing it into 8 separate bins and counting the frequency for each bin.

# %%
import matplotlib.pyplot as plt
df['Age'].dropna().hist(bins=8,edgecolor='black')
plt.title("Histogram of Age")
plt.xlabel("Age")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 10) A boxplot can also be used to show the distribution of values for each attribute.

# %%
pairs=[('Survived', 'PassengerId'),
        ('Pclass', 'Survived'),
          ('Age', 'Pclass'), ('SibSp', 'Age'),
            ('Parch', 'SibSp'), 
            ('Fare', 'Parch'),
            ]
fig, axes = plt.subplots(len(pairs), 1, figsize=(8, 20))  

for i,(x,y) in enumerate(pairs):
    ax = axes[i]  # Access subplot
    ax.scatter(df[x], df[y], edgecolors='k', alpha=0.5)
    ax.set_title(f"{x} vs {y}")  # Set title for each plot
    ax.set_xlabel(x)
    ax.set_ylabel(y)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 11)  Display scatter plot for any 5 pair of attributes , we can use a scatter plot to visualize their joint distribution.
